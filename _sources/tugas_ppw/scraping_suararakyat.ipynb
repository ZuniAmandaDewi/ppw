# %% [markdown]
# # Scraping suararakyat.id

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrap_suararakyat(link,hal,kategori):
    category = kategori
    data=[]
    base_url = link
    for page in range(1, hal + 1):
        url = f'{base_url}page/{page}/'
        # print(f"Scraping page: {url}")
        response = requests.get(url)
        if response.status_code == 200:
          soup = BeautifulSoup(response.content, 'html.parser')
          blok= soup.find('div', class_='block-content')
          articles = blok.find_all('article')
          for article in articles:
            link = article.find('a')['href']
            # print(f"link: {link}")
            title = article.find('h2', class_='is-title post-title').text.strip()
            # print(f"Judul: {title}")
            content_response = requests.get(link)
            if content_response.status_code == 200:
                content_soup = BeautifulSoup(content_response.content, "html.parser")
                article_content = content_soup.find('div', class_='entry-content')
                if article_content:
                    content_text = ""
                    for paragraph in article_content.find_all(['p', 'h2', 'h3', 'h4', 'h5']):
                        content_text += paragraph.get_text(strip=True).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                    # print(content_text)
                    data.append([title,content_text,category])
    return data

# %%
pendidikan = scrap_suararakyat('https://suararakyat.id/category/pendidikan/',10,'Pendidikan')

# %%
politik = scrap_suararakyat('https://suararakyat.id/category/politik/',6,'Politik')

# %%
sport = scrap_suararakyat('https://suararakyat.id/category/olahraga/',4,'Sport')

# %%
hasil1 = pd.DataFrame(pendidikan, columns=['Judul', 'Isi', 'Kategori'])
hasil2 = pd.DataFrame(politik, columns=['Judul', 'Isi', 'Kategori'])
hasil3 = pd.DataFrame(sport, columns=['Judul', 'Isi', 'Kategori'])

# %%
combined_df = pd.concat([hasil1, hasil2, hasil3]).reset_index(drop=True)
combined_df
# Out:
#                                                  Judul  \
# 0    Audiensi dengan Wadek Kemahasiswaan  Fakultas ...
# 1    Tingkatkan Keterampilan Bahasa Inggris, PPB UI...
# 2    Puluhan Materi Agama MTs Hingga MA di Sampang ...
# 3    PPK-O Penalaran UTM Lahirkan Inovasi Konsep Sm...
# 4    Tim Pengabdian Masyarakat UTM Berhasil Ciptaka...
# ..                                                 ...
# 140  Tak Mencapai Target, KONI Sampang di Minta Int...
# 141  Skor 7-0 Untuk PP. Al Jauhariyah Banyuates Pad...
# 142  Pemkab dan Dispora Dukung Perkumpulan Sepak bo...
# 143     PSSI Liga Santri Piala KASAD Kabupaten Sampang
# 144  Atlet Cabor Taekwondo Sampang Tasyakuran di Ko...
#
#                                                    Isi    Kategori
# 0    BANGKALAN, Suararakyat.id– Mahasiswa Fakultas ...  Pendidikan
# 1    JAKARTA, Suararakyat.id– Pusat Pengembangan Ba...  Pendidikan
# 2    SAMPANG, Suararakyat.id– Media Literasi Kampus...  Pendidikan
# 3    BANGKALAN, Suararakyat.id– Tim Program Penguat...  Pendidikan
# 4    SUMENEP, Suararakyat.id– Mahasiswa Pengabdian ...  Pendidikan
# ..                                                 ...         ...
# 140  SAMPANG,suararakyat.id– Ketua Komite Olahraga ...       Sport
# 141  SAMPANG, suararakyat.id – Kompetisi Sepakbola ...       Sport
# 142  PAMEKASAN, suararakyat.id – Perkumpulan Sepakb...       Sport
# 143  SAMPANG, suararakyat.id – Pembukaan kompetisi ...       Sport
# 144  SAMPANG, Suararakyat.id – Kegiatan tasyakuran ...       Sport
#
# [145 rows x 3 columns]

# %%
df = combined_df.sample(frac=1).reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/ppw/tugas/tugas_ppw/suararakyat.csv', index=False)

# %%
df
# Out:
#                                                  Judul  \
# 0    Hadiri Seminar Nasional, Slamet Ariyadi Gemble...
# 1    SIAP !! Cerdaskan Siswa-Siswi SD Negeri Giliba...
# 2    Direktur Pasca Sarjana IAIN Madura Ajak Mahasi...
# 3    MK Tolak Gugatan Usia Minimal Capres-Cawapres ...
# 4    Sukes Gelar Festival Nasyid Islami :Al-Amin Al...
# ..                                                 ...
# 140  MK Tolak Gugatan Usia Minimal Capres-Cawapres ...
# 141  BEM SI Akan Gelar Aksi Demo Besar-Besaran pada...
# 142  Sportif Cup 2022 : Tim Voli Remaja BPRS siap T...
# 143  Bupati Sumenep Buka JJC, Minta Guru Memberikan...
# 144  FL2MI Korda Madura Sukses Gelar Deklarasi Keme...
#
#                                                    Isi    Kategori
# 0    PAMEKASAN,Suararakyat.id– Slamet Ariyadi luang...  Pendidikan
# 1    Mahasiswa UTM adakan Gerakan Memasyarakatkan M...  Pendidikan
# 2    PAMEKASAN,Suararakyat.id– Kegiatan Kuliah Peng...  Pendidikan
# 3    JAKARTA, Suararakyat.id–Mahkamah Konstitusi (M...     Politik
# 4    SUMENEP,Suararakyat.id– Dalam Rangka Memeriahk...  Pendidikan
# ..                                                 ...         ...
# 140  JAKARTA, Suararakyat.id–Mahkamah Konstitusi (M...     Politik
# 141  JAKARTA, Suararakyat.id– Badan Eksekutif Mahas...     Politik
# 142  SUMENEP,Suararakyat.id– Tim kuat Remaja BPRS a...       Sport
# 143  SUMENEP,Suararakyat.id– Dinas Pendidikan (Disd...  Pendidikan
# 144  PAMEKASAN,Suararakyat.id– Forum Lembaga legisl...  Pendidikan
#
# [145 rows x 3 columns]

# %%
pd.crosstab(index=df['Kategori'], columns='count')
# Out:
# col_0       count
# Kategori
# Pendidikan     94
# Politik        18
# Sport          33
